# %% [markdown]
# This notebook follows the development of the algorithms for weighted scoring and a simple search engine for movies related to a chosen actor.

# %%
import pandas as pd
import numpy as np

# %%
# %run ./support_functions.ipynb

# %%
data = pd.read_csv("data_preprocessed_v2.csv")

# %%
head(data)
# Out:
#         uids                     titles                        genres ratings  \
# 0  tt0066026                       MASH            Comedy, Drama, War       R
# 1  tt0065988             Little Big Man      Adventure, Comedy, Drama   PG-13
# 2  tt0066011                 Love Story                Drama, Romance      PG
# 3  tt0065134  Two Mules for Sister Sara       Adventure, Romance, War      GP
# 4  tt0065421             The AristoCats  Animation, Adventure, Comedy       G
#
#    scores  votes  lengths            directors  \
# 0     7.4  67665      116        Robert Altman
# 1     7.6  32952      139          Arthur Penn
# 2     6.9  31300      100        Arthur Hiller
# 3     7.0  24029      116           Don Siegel
# 4     7.1  94523       78  Wolfgang Reitherman
#
#                                                stars  \
# 0  Donald Sutherland, Elliott Gould, Tom Skerritt...
# 1  Dustin Hoffman, Faye Dunaway, Chief Dan George...
# 2  Ali MacGraw, Ryan O'Neal, John Marley, Ray Mil...
# 3  Clint Eastwood, Shirley MacLaine, Manolo Fábre...
# 4  Phil Harris, Eva Gabor, Sterling Holloway, Sca...
#
#                                         descriptions  year
# 0  The staff of a Korean War field hospital use h...  1970
# 1  Jack Crabb, looking back from extreme old age,...  1970
# 2  A boy and a girl from different backgrounds fa...  1970
# 3  Nun Sara (Shirley MacLaine) is on the run in M...  1970
# 4  With the help of a smooth talking tomcat, a fa...  1970

# %%
info(data)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 298048 entries, 0 to 298047
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   uids          298048 non-null  object
#  1   titles        298048 non-null  object
#  2   genres        298048 non-null  object
#  3   ratings       298048 non-null  object
#  4   scores        298048 non-null  float64
#  5   votes         298048 non-null  int64
#  6   lengths       298048 non-null  int64
#  7   directors     298048 non-null  object
#  8   stars         298048 non-null  object
#  9   descriptions  298048 non-null  object
#  10  year          298048 non-null  int64
# dtypes: float64(1), int64(3), object(7)
# memory usage: 25.0+ MB

# %%
data.shape
# Out:
# (298048, 11)

# %% [markdown]
# #### Inspect available ratings

# %%
data.ratings.unique()
# Out:
# array(['R', 'PG-13', 'PG', 'GP', 'G', 'M/PG', 'Not Rated', 'NC-17', 'X',
#        'None', 'M', 'Unrated', 'TV-G', 'TV-14', 'TV-MA', 'TV-PG',
#        'Approved', 'TV-13', 'Passed', 'TV-Y7', 'TV-Y7-FV', 'MA-13', 'AO',
#        'E10+', '(Banned)', 'Open', 'TV-Y', 'E', '12', 'MA-17', 'T', '18'],
#       dtype=object)

# %% [markdown]
# #### Inspect available genres

# %%
genres = set()

# %%
for i in range(data.shape[0]):
    glist = [el.strip() for el in data.loc[i].genres.split(",")]
    for g in glist: genres.add(g)

# %%
genres
# Out:
# {'Action',
#  'Adult',
#  'Adventure',
#  'Animation',
#  'Biography',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Game-Show',
#  'History',
#  'Horror',
#  'Music',
#  'Musical',
#  'Mystery',
#  'News',
#  'Reality-TV',
#  'Romance',
#  'Sci-Fi',
#  'Sport',
#  'Talk-Show',
#  'Thriller',
#  'War',
#  'Western',
#  'unknown'}

# %%
len(genres)
# Out:
# 27

# %% [markdown]
# #### Inspect available actors

# %%
actors = set()

# %%
for i in range(data.shape[0]):
    alist = [el.strip() for el in data.loc[i].stars.split(",")]
    for a in alist: actors.add(a)

# %%
actors
# Out:
# {'',
#  'Menaka Peiris',
#  'Anwari',
#  'Nick Canterucci',
#  'Alkis Giannakas',
#  'Nelson Rodríguez',
#  'Maria Vittoria Garlanda',
#  'Karen Contreras',
#  'Anita Ericsson',
#  'Franciele Mazetti',
#  'Mangal Chowdhury',
#  'Parisa Fitz-Henley',
#  'Mohammad Ali Abtahi',
#  'Svetlana Janjanin',
#  'Yue',
#  'Bailey Gambertoglio',
#  'Rubén Ochandiano',
#  'Krishnam Raju',
#  'Helmencia Alexander',
#  'Yi Wang',
#  'Antoni Ruiz',
#  'Yessy Gusman',
#  'Olga Schoberová',
#  'Gabriela Benacková',
#  'Yanet Cuevas',
#  'Leon Samuel Kilian',
#  'Mehmet Birkiye',
#  'Kim Haugan Andersen',
#  'Mona Hofland',
#  'Bogdan Magomedov',
#  'Amber Styles',
#  'Shannon Barry',
#  'Tony Ramos Wright',
#  'Chingsum Luk',
#  'Rainer-Maria Pfeffer',
#  'Martin Compston',
#  'Anton Grobler',
#  'Russell Dykstra',
#  'Enrique Imperio',
#  'Robert Braxton',
#  'Hongisto',
#  'Eugenio Lopez Matos',
#  'Deborah Wakeham',
#  'Thomas Kerr',
#  'Johannes Freitag',
#  'Christine Hébert',
#  'Justin Bilancieri',
#  'Zarina Tadjibaeva',
#  'Oxmo Puccino',
#  'Achmed Xussein',
#  'Sofia Vigliar',
#  'Kyoji Yamaguchi',
#  'Tony Mabesa',
#  'Wes Conner',
#  'Alan Morris',
#  'Rushikesh Bhadane',
#  "D'Andre Davis",
#  'Sonny Mandal',
#  'Phylip Harries',
#  'Glenn Mure',
#  'Mariella Devia',
#  'Armando de Leon',
#  'Hanna Bjorklund',
#  'John Wagner',
#  'Charlotte Beglinger',
#  'Lila Korkalo',
#  'Jack Stahlmann',
#  'Thomas Quinn',
#  'Jonathan Dwyer',
#  'Jeremy Drakes',
#  'Uwe Epperlein',
#  'Muhtesem Tozum',
#  'Reginald Baskerville',
#  'Mark Helmericks',
#  'Eve',
#  'Carlos Villagrán',
#  'Anthony Rowlands',
#  'Johnny Ray Meeks',
#  'Ion Beregoi',
#  'Corinna Long',
#  'Judah Bauer',
#  'Sonia Roszczuk',
#  'Jonas Togay',
#  'Emma Wu',
#  'Rashmika Mandanna',
#  'Aaron Green',
#  'James Collier',
#  'Philippe Thelen',
#  'René Alfonso',
#  'Gandong Cervantes',
#  'Thrissur Anand',
#  'Nika Khitrova',
#  'Zeynep Aksu',
#  'Michelle Schulman',
#  'Florencia Contreras Stevens',
#  'Kevin Osborne',
#  'Lars van Hegnet',
#  'John Alex Castillo',
#  'Patrick Birmel',
#  'Nafa Urbach',
#  'Chloe Teddy Hannah-Drullard',
#  'Jeffrey Gonzales',
#  'Jessica Harthcock',
#  'Terrell Hardaway',
#  'Valery Guryev',
#  'Armando Buttafava',
#  'Meme Ditshego',
#  'Sarah Abdulrahman',
#  'Ancilla Tilia',
#  'Mihalis Georgakopoulos',
#  'Marce Walsh',
#  'Gürel Yontan',
#  'Feng Zhao',
#  'Penda Daly Sy',
#  'Rolando Ledesma',
#  'Nantarat Sawaddikul',
#  'Christos Takas',
#  'Todd Poudrier',
#  'Lydia Toumazou',
#  'Konstantin Shkurko',
#  'Cristina Mullins',
#  'Yi-Wen Tian',
#  'Todd Humes',
#  'Boranbek Akhmetov',
#  'Sona Nair',
#  'Robert McGill Jr.',
#  'David Bowie',
#  'James Saintil',
#  'Fern Lim',
#  'Gen Ichikawa',
#  'Malek Bechar',
#  'Jason Nohovig',
#  'David Atwood',
#  'Özlem Yazici',
#  'Mark Rendall',
#  'Duda Wendling',
#  'Ethel Begay',
#  'Garima Panta',
#  'Nita Fernando',
#  'Cindel Chartrand',
#  'Khashayar',
#  'Savi Sidhu',
#  'Steve Railsback',
#  'Jocelyn Brown',
#  'Nathalie Bilodeau',
#  'Gaston Belanger',
#  'Joyram',
#  'Ryan Jason Cook',
#  'Jeremy Shadlow',
#  'Emmerich Schäffer',
#  'Udayanthi Kulatunga',
#  'Eldon Hagen',
#  'Rebecca Burleson',
#  'Katsumi Muramatsu',
#  'Ashley Aliprandi',
#  'Roel Hissel',
#  'Donnalee Austen',
#  'James Edward Holley',
#  'Milan Bandic',
#  'Ingrid Lacey',
#  'Olga Chinopoulou',
#  'Celia Kwok',
#  'Yuki Kawashima',
#  'Jannie Faurschou',
#  'Sigalon Sagna',
#  'Danae Skiadi',
#  'Sagor',
#  'Nathaniel Beliveau',
#  'Stefania Caracciolo',
#  'Cloé Boisselier',
#  'Ignacio Lozano',
#  'Liz Dufresne',
#  'Yvetta Blanarovicová',
#  'Jessica Edström',
#  'Marco Gherardi',
#  'Matthew Dieu Allen',
#  'Guido Celano',
#  'Shayan Bayat',
#  'Russell LaDue',
#  'Ravdeep Singh Bajwa',
#  'Settie Chappell',
#  'Nico Milas',
#  'Hrvoje Perc',
#  'James Scott Flannery',
#  'Chris Morrell',
#  'Linda S. Wong',
#  'Bujor Macrin',
#  'Linda Cerabolini',
#  'Christopher M. Bettencourt',
#  'Joe Babcock',
#  'Ashley Bracken',
#  'Marie-Agnès Then',
#  'Claudia Aguirre',
#  "Maria D'Amato",
#  'Simon Fox',
#  'Mathis Crusson',
#  'Tindra Hillestad Pack',
#  'Karl Glusman',
#  'Julianna Barninger',
#  'Irlanda Moreno',
#  'Oliver Tompsett',
#  'Pierre Walker',
#  'Mason Castree',
#  'Wai-Kin Lam',
#  'Paul Fellermeier',
#  'Chris Cote',
#  'Giulio Lopes',
#  'Gift Igweh',
#  'Bruno Ferrari',
#  'Mireille Darc',
#  'Manoj Shah',
#  'Roland Topor',
#  'Maren Thurm',
#  'William Gates',
#  'Lisa Bolzonello',
#  'Jennifer Westbrook',
#  'Marty Brem',
#  'Rajeshwari Kharat',
#  'Fortune Belisle',
#  'Criss Firsberg',
#  'Seung-hyeon Bong',
#  'Nicolás Ibieta',
#  'Emily Hoffman',
#  'Reid Landris',
#  'Roger Huckstex',
#  'Katerina Janecková',
#  'Rommel Chika',
#  'Sd.M. Basha',
#  'Michael Brandes',
#  'Roberto Azevedo',
#  'Parker Lane',
#  'Gilles Boetsch',
#  'Yuka Katô',
#  'Angie Jibaja',
#  'Liina Vahtrik',
#  'Burke Morgan',
#  'G.J. Echternkamp',
#  'Dmitriy Dykhovichnyy',
#  'Anna Jimskaia',
#  'Andrew Beachum',
#  'Bruno Solo',
#  'James Campbell',
#  'Luke Perry',
#  'Kermith Chung',
#  'Sarah Krasnow',
#  'Leslie Steele',
#  'Maliheh Nazari',
#  'Michel Cressolle',
#  'Mike',
#  'Ana Rita Franco',
#  'Tal Kalay',
#  'Sandra Destenave',
#  'Akshara Suresh',
#  'Rafael Federman',
#  'Richard Chaves',
#  'Christian Reyes',
#  'Karen Talbot',
#  'Cheyenne Mack',
#  'Anthony Danna',
#  'Joe Tompkins',
#  'Lembit Eelmäe',
#  'Silvia Bestagno',
#  'Jordan Allison',
#  'Ebru Sanci',
#  'Marilou Lopes-Benites',
#  'Drake Gibson',
#  'Robert Correa',
#  'Gayathrie',
#  'Akle Guruji',
#  'Rolf Pedersen',
#  'Alan Pottinger',
#  'Parth Naik',
#  'Kristina Buozyte',
#  'Rika Imai',
#  'Hattori Muo',
#  'Rebecca Johnson',
#  'Josh Golga',
#  'T.V. Chandran',
#  'Maury Sterling',
#  'Martti Sivonen',
#  'Sita Spada',
#  'Hongwei Gao',
#  'Tajbakhsh Fanaiyan',
#  'Kálmán Varju',
#  'Mariko Okada',
#  'Csaba Tóth',
#  'Wesley Apfel',
#  'Stephane Vadim',
#  'Sérgio Fernandes',
#  'Whitney Hoy',
#  'Robert Corbitt',
#  'Christopher Dalton',
#  'Ha-na Ahn',
#  'Destiny Soria',
#  'Jabraan Ismail',
#  'Hugo Maerten',
#  'Lu-Yi Chuo',
#  'Jake Willis',
#  'Brendan Archer',
#  'Chelsea Low',
#  'Catherine Black',
#  'Nathalie Sartiaux',
#  'Max Mégy',
#  'Adam McCabe',
#  'Benedict Mazurek',
#  'Wah Hong',
#  'Liam Carney',
#  'Éva Vándor',
#  'Gayle Lorraine',
#  'Patricia Lacy Aiken',
#  'Laurent Bateau',
#  'Mandy Muenzer',
#  'Jamie Switch',
#  'Bozena Dykiel',
#  'Naír',
#  'Filipe Cochofel',
#  'Charlie Berry',
#  'Elio Ortíz',
#  'John Paul Piazza',
#  'Patrick Caporuscio',
#  'Maria Guido',
#  'Stella Hodge',
#  'Hiro',
#  'Nair Bello',
#  'Axle Gunn',
#  'Ralph Bowsher IV',
#  'Paul Branco',
#  'Jacky Arnal',
#  'Isabelle Fortea',
#  'Richard Zihmanis',
#  'Eliana Miglio',
#  'Francois Bergeon',
#  'Dany Boon',
#  'Mia Burke',
#  'Charito Solis',
#  'Jae-yong Lee',
#  'Nick Lorenz',
#  'Rafael Diaz-Wagner',
#  'Wesley Stiller',
#  'Takao Iida',
#  'Sherine Wong',
#  'Serge Fargier',
#  'Orien Richman',
#  'Roy Day',
#  'Haydée Padilla',
#  'Jala Fahmi',
#  'Rolando Brenes Calvo',
#  'Yûki Kubota',
#  'Lucas Araujo',
#  'Sean Gordon',
#  'Yumi Uchiyama',
#  'Margot Bigland',
#  'Ellen Hillman',
#  'Rikako Itô',
#  'Flor Salanga',
#  'Anusha Gargi',
#  'Vincent Sala-Tenna',
#  'Julia Berensen',
#  'Nick Renaud',
#  'Victoria Fonseca',
#  'Thomas Cleary',
#  'Savanna Sears',
#  'Stuart Brent',
#  'Anna Karin',
#  'Matthew Scott',
#  'Nakazeko Mie',
#  'Emily Van Raay',
#  'Tammy Massa',
#  'Jason Anderson',
#  'Silviya Kozareva',
#  'Tatyana Grauz',
#  'Jerry Walter',
#  'Jgor Barbazza',
#  'Kriz Chris Henri Harriz',
#  'Darin Campbell',
#  'Tomoyo Yamaki',
#  'Ako Asaka',
#  'Eduardo Pavlovsky',
#  'Adil Sheikh',
#  'Diana Bologna',
#  'Cameron James',
#  'Gareth Pugh',
#  'E. Gus Cothran',
#  'Feng Tien',
#  'Fiona Forbes',
#  'Joseph Price',
#  'Carolien van de Brandhof',
#  'Eric Clavering',
#  'Salem Murphy',
#  'Abubakar Jamil',
#  'Lamine Dolo',
#  'Gaudenz Huebscher',
#  'Melanie Hill',
#  'Jorge A.N.',
#  'Kian Chambers',
#  'Aditi Govitrikar',
#  'Gürkan Kaya',
#  'Rola Roukbi',
#  'Christian Kane',
#  'Yutaka Takeuchi',
#  'Lien-Shi Chin',
#  'Waltraut Galler',
#  'Ali Sadeghi',
#  'João Salustiano Soares',
#  'Darren Morfitt',
#  'Luc Ponette',
#  'Burcu Kutluk',
#  'Amy Currie',
#  'Alessandra Panelli',
#  'Andie Falconi',
#  'Ashley Hamilton',
#  'Shiv Tendon',
#  'Rinil Routh',
#  'Eva Wilma',
#  'Tom Leeb',
#  'Bo Phillips',
#  'Marylène Bergmann',
#  'Roza Akino',
#  'Thomas Millet',
#  'Amina Eleonora Bergrem',
#  'Burt Lancaster',
#  'Rory J. Saper',
#  'Jin Hiramaki',
#  'LeJuane Bowens',
#  'Vance Major',
#  'Eugenio Arnao',
#  'William Curtis Coppersmith',
#  'Mallikarjun Devaramane',
#  'Joon Kim',
#  'Romuald Bourdon',
#  'Lamaid Ruekkhumyee',
#  'Sammi-Jack Martincak',
#  'Vikas Giri',
#  'Cyril Couton',
#  'Emmanuelle Debever',
#  'Marco Licht',
#  'Martín Abrisqueta',
#  'Chloe Larson',
#  'Carol Kane',
#  'Mark Wilson',
#  'Veronica Mazza',
#  'Susanta Chatterjee',
#  'Warren Lincoln',
#  'Robert Beltran',
#  'Boyan Karakolev',
#  'Pitradjaya Burnama',
#  'Ivana Pavlakovic',
#  'Robert Ascherman',
#  'Gloria Georgina Seddon',
#  'Patrick Ascher',
#  'Alice Albergaria Borges',
#  'Manuel Jose Contreras',
#  'Keith D. Robinson',
#  'Tatiana Niculescu-Bran',
#  'Alvin Prouder',
#  'Moran Rosenblatt',
#  'Jean-Luc Jordan',
#  'Carlos Gomes',
#  'Parvindokht Yazdanian',
#  'Tom De Roeck',
#  'Loren W. Lepre',
#  'Ari Sorrentino',
#  'Robert Palmer Watkins',
#  'Lance Irwin',
#  'Mildred Levine',
#  'Poornima',
#  'Tage Larsen',
#  'Tunca Yönder',
#  'Tony Carrera',
#  'Dover Koshashvili',
#  'Emilia Clarke',
#  'Ethan Philbeck',
#  'Carl Hagenbeck Jr.',
#  'Arantxa Costas',
#  'Zhiyang Liu',
#  'Tom Adair',
#  'Lauren Byrnes',
#  'Paul Walsh',
#  'Bobby Holt',
#  'Robert Rickman',
#  'Wendi Starling',
#  'Billy Miller',
#  'Gregory Sheppard',
#  'Dani Daniels',
#  'Mavie Hörbiger',
#  'Kim Cheol-Hyeon',
#  'Györk Szakonyi',
#  'Shimmy Gray-Miller',
#  'Sai Shetra',
#  'Jaya Prada',
#  'Michael Allinson',
#  'Nedjad Bakalovic',
#  'Yoon-Seong Kim',
#  'Alison Alampi',
#  'Lucien van Geffen',
#  'Vanina Balena',
#  'Robert Bergren',
#  'Nick Isel',
#  'Anatoliy Falkovich',
#  'Vanessa Viola',
#  'Kelley Johnson',
#  'Tom Burruss',
#  'Emidio Clementi',
#  'Kartik Elangovan',
#  'Lucian Msamati',
#  'Daniel Kolenda',
#  'Richard Demarco',
#  'Kate Woo',
#  'Gregor Xythe',
#  'Catherine Hagarty',
#  'Agnieszka Prokopowicz',
#  'Jorge Alejandro Fegan',
#  'Jessica Gartland',
#  'Shadi Alfons',
#  'Philip Anglim',
#  'Dries Smits',
#  'Elisa Beuger',
#  'Mason Coleman',
#  'Tom Trouffier',
#  'David Chain',
#  'Lucien Eisenach',
#  'Melody Anderson',
#  'Prosenjit Bora',
#  'Ömer Atakan',
#  'Paskal Vaklev',
#  'Jaime Correa',
#  'Kh. Kiziryan',
#  'Alysia Reiner',
#  'Guerrino Casamonica',
#  'Jane Dodd',
#  'Magdalena Hrubá',
#  'Max Brofeldt',
#  'Peter Garell',
#  'Gobby Wong',
#  'Danuta Borowiecka',
#  'Faruque Azam',
#  'Charlie Watts',
#  'Dan Coplan',
#  'May Pascual',
#  'Bazzoli Andrea',
#  'Eun-Chong Go',
#  'Jadwiga Baranska',
#  'John Tallman',
#  'Ariadne Blakey',
#  'Amanda Leonard',
#  'Yumi Motoyama',
#  'Desiré Gardner',
#  'Tankred Dorst',
#  'Aidar Mukhametzhanov',
#  'Juan Andrés Silva',
#  'Tia Bajpai',
#  'Stephen Conroy',
#  'Kädi Metsoja',
#  'Ray Benitez',
#  'Agung Saga',
#  'Xiyan Sun',
#  'Bruno Holger Karlström',
#  'Joel Burns',
#  'Mykayla Booth',
#  'Alexander Wolf',
#  'Race Owen',
#  'Tani Guthrie',
#  'Jerzy Lapinski',
#  'Christina Bomberry',
#  'Elizabeth Muñoz',
#  'Jojo Goh',
#  'Lawrence Blake',
#  'Rico Maldi',
#  'Masami Ishii',
#  'Kamaran Abdalla',
#  'Kienuwa Davis',
#  'Caitlin Matthews',
#  'Cecil Shuckey Duckey Armstrong',
#  'Anita Grube',
#  'Étienne Guichard',
#  'Daniel McDonald',
#  'Stefan Glowacz',
#  'Máximo Kirchner',
#  'Wesley John',
#  'Aziz M. Osman',
#  'Christer Engen',
#  'Yeong Lookyee',
#  'Julie Gomez',
#  'Kelvin McCray',
#  'Taylor Burns',
#  'Kerry McGann',
#  'Kaiser Kuo',
#  "Kel O'Neill",
#  'Mizuho Toyota',
#  'Volker Figge',
#  'Rafael Albarran',
#  'Tucker Johnson',
#  'Raf Mauro',
#  'Thomas Steven Varga',
#  'Sonja Sippala',
#  'Brad Marshall',
#  'Ismail Ahmad',
#  'Chris Levine',
#  'Pavlo Li',
#  'Robin Sherwood',
#  'Nick Brocha',
#  'Carl Andre',
#  'Anna Kalaitzidou',
#  'Sarah Bingham',
#  'Branden Chowen',
#  'Cassandra Jacobsen',
#  'Dani Filth',
#  'C.J. Berdahl',
#  'Vincent Soberano',
#  'André Cerbe',
#  'Yoshikawa Eri',
#  'Phil Hawn',
#  'Ryan Whitelock',
#  'Ako Fujimoto',
#  'Jose Amaya',
#  'Guy Bannister',
#  'Rawkan Binbella',
#  'Jay Saldi',
#  'Desmond Locke',
#  'Nicolas Vaporidis',
#  'Sydney Bonar',
#  'Nurhan Damcioglu',
#  'Vincent Ozanon',
#  'Morrie Halper',
#  'Ana Maria Guran',
#  'Amber Davila',
#  'Diego Rivera',
#  'Jeff Caster',
#  'Michael Andreasen',
#  'Sabrina Machado',
#  'Ki Kusumo',
#  'Ron E. Harris',
#  'Yogesh',
#  'Lilia Ortega',
#  'Yûka Eda',
#  'Ahmet Aydin',
#  'Peter Vander Meulen',
#  'Rosa de Castilla',
#  'António Andrade',
#  'Zheng Gu',
#  'Ahsan Baksh',
#  'Walter Ardila',
#  'Jesse Plemons',
#  'Rafael Eliasi',
#  'Angela Berliner',
#  'David F. Hughes',
#  'Billy Brockington II',
#  'Cumulus',
#  "Andrew D'Angelo",
#  'Anatoliy Pustokhin',
#  'Sandy Hackett',
#  'Faras Fatik',
#  'Enric Cervera',
#  'Gavin MacLeod',
#  'Bridget Opfer',
#  'Roberto Maldera',
#  'Esrom Jayasinghe',
#  'Natsumi Takamori',
#  'Kenny Boulet',
#  'Atilla Olcay',
#  'Judy Balaban',
#  'Barnaby Metschurat',
#  "Alain D'Haeyer",
#  'Norman Yemm',
#  "Lil' Boss",
#  'Manuel Porto',
#  'Dane Cannon',
#  'Opara Machi',
#  'Mario Desmarais',
#  "Jere' Folley Chaisson",
#  'Ratu Sikumbang',
#  'Jeremy Pereira Da Silva',
#  'Suebsai Boonveerabut',
#  'Jayalalitha',
#  'Yi-Lung Lu',
#  'Scott Piper',
#  'Ilona Schult',
#  'Gregory Du',
#  'Jin Woo',
#  'Metin Keçeci',
#  'Lola Amores',
#  'Jonathan Cobb',
#  'Alex Dimitriades',
#  'Daniel Blunck',
#  'Holly Manning',
#  'Chung-Ah Lee',
#  "Caroline O'Connor",
#  'Beth Campbell',
#  'Ji-hae Kim',
#  'Huy Khanh',
#  'Petronella Nygaard',
#  'Émile Schneider',
#  'Brian Byus',
#  'Jimmine Arizmendi',
#  'Dewitt Duncan',
#  'Louisa Hamdi',
#  'Neil Feng',
#  'Elliot Balchin',
#  'Eric Spade Rivas',
#  'Caterina Consoli',
#  'Carl-Einar Häckner',
#  'Adam Vernier',
#  'Jenny Roa',
#  'Difaf Al-Khoja',
#  'Leticia Jimenez',
#  'Mark Bland',
#  'Kelly Nick',
#  'Charles Aidikoff',
#  'Jason A. Kendall',
#  'Seol-ah Yu',
#  'Tikoy Aguiluz',
#  "Maryke Del'Castillo",
#  'Clare Carey',
#  'Nick McMaster',
#  'Dominic Hure',
#  'Lina Bradford',
#  'Rob Harmon',
#  'Peter Story',
#  'Andy Goldsworthy',
#  'Akiko Seri',
#  'James Morrison',
#  'Carmen Zielinski',
#  'Liam Maves',
#  'Brice Fournier',
#  'Ben Shields',
#  'Daniel Welk',
#  'Håvard Jackwitz',
#  'Boris Orlov',
#  'Anthony Snow',
#  "Marcus M'teo",
#  'Bartlomiej Firlet',
#  'Darla Hill',
#  'Jeff Bee',
#  'Kristina Karst',
#  'Claude Evrard',
#  'Tom Swift',
#  'Patt Franklin',
#  'Josh Bernstein',
#  'François Dalle',
#  'Rachel Kitson',
#  'Jimmy Cliff',
#  'James Watson',
#  'Nashwa Mustafa',
#  'Jennifer Steele',
#  'So-eun Choi',
#  'Junji Chiba',
#  'Diego Masson',
#  'David Benveniste',
#  'Christian Borys',
#  'Peter Chan',
#  'Heleya de Barros',
#  'Michael Solarez',
#  'Shishir Sharma',
#  'Will Bledsoe',
#  'Michael Evanichko',
#  'Jason Burnham',
#  'Darryl McDaniels',
#  'Scott Drebit',
#  'Sakiys Ahmed',
#  'Hemi Che',
#  'Rosilin',
#  'Isabel Tolosa',
#  'Bryan Session',
#  'Cheng Li',
#  'Peyuand Ismael Hawez',
#  'Jamie Agius',
#  'Mirjana Deak',
#  'Cory Okouchi',
#  'Sheila Ysrael',
#  'Warwick Moss',
#  'Jean-Pierre Loustau',
#  'Daniel Alvarez',
#  'Allan Kuljus',
#  'Wolke Hegenbarth',
#  'Alex Galper',
#  'Mame Ndoumbé',
#  'Michelle Bowes',
#  'Smokey Robinson',
#  'Mikolaj Matczak',
#  'Alex Lucchesi',
#  'Peter Astridge',
#  'Beth Naef',
#  'Alessandra Tognini',
#  'Harry Lloyd',
#  'Susan Callaway',
#  'Swapna Pati',
#  'Haruna Friday',
#  'Nithya Shetty',
#  'Réti László',
#  'Lewin Manly',
#  'William Stancik',
#  'Yolanda Maure',
#  'Jyn Hall',
#  'Lyn Pierse',
#  'Kunto Aji',
#  'Richard Halsey',
#  'Béatrix Van Til',
#  'Xan Manning',
#  'Giselle Allen',
#  'Cybele Smith',
#  'William Alonzo',
#  'Yihan Liu',
#  'Erik Williams',
#  'Yûma Satô',
#  'Griffin Newman',
#  'Adhisty Zara',
#  'Horst Bubeck',
#  'Pieter Leegwater',
#  'Ugur Beceren',
#  'Titos Menchaca',
#  'Sahil Jadhav',
#  'Advencula Alcantara',
#  'Don Bergsten',
#  'Sanjay Bagul',
#  'Alonzo Duncan',
#  'Tzvika Korman',
#  'James Galanos',
#  'Philip Fowler',
#  'Bora Ahmet-Altun',
#  'Sietske Bergsma',
#  'Martin Zounar',
#  'Francesca Prandi',
#  'Peng Chi',
#  'Steven Kahler',
#  'Johannes Demmel',
#  'Wai-Yin Lam',
#  'Casey Fitzgerald',
#  'Peter Knight Silander',
#  'Lito Acuña',
#  'Dick Israel',
#  'Laura Otis',
#  'Carl Oliverio Jr',
#  'Tal Grushka',
#  'Anna Costamagna',
#  'Patrick McCormack',
#  'Minda Lorando',
#  'Marci Hamilton',
#  'Gordon Hirabayashi',
#  'SABU',
#  'Anthony Gnome Willis',
#  'Carolina Charry',
#  'Nanette K. Martin',
#  'Rebecca Hampton',
#  'Irakli Mshvildadze',
#  'Andrea Narciso',
#  'Lisa Edwards',
#  'Scott Gairdner',
#  'Christopher Hall',
#  'E. Otgon-Chimeg',
#  'Susan Lankester',
#  'Leonardo Santini',
#  'Kacey Arnold',
#  'Lane Davies',
#  'Dina Rosenmeier',
#  'Al Madrigal',
#  'Cheryl Powell',
#  'Tomokazu Miura',
#  'Ingrid Bolsø Berdal',
#  'Reena Jadhav',
#  'Feiyu Cai',
#  'Toula Galani',
#  'Ana Naranjo',
#  'Campbell Morrison',
#  'Elinor W. Gadon',
#  'Kylie Bracknell',
#  'Tetsuya Kondô',
#  'Darko',
#  'Alexy Voevoda',
#  'Irina Tschistjakowa',
#  'León Klimovsky',
#  'Franco Bizzoccoli',
#  'Nicole Doring',
#  'Doaa Ereikat',
#  'Dao Mayuri',
#  'Tomoko Kihi',
#  'Vibha Jakatdar',
#  'Phil Freeborn',
#  'Jirí Sedlácek',
#  'Qyoko Kudo',
#  'Scott Blakeman',
#  'Nese Özcan',
#  'Shelly Desai',
#  'Oumarou Ganda',
#  'Mia de Los Reyes',
#  'Georgia Chris',
#  'Esther Supreeleela',
#  'Jose Miguel Jimenez',
#  'Alain de Botton',
#  'Ronald Goodman',
#  'Madyson Pellegrino',
#  'Hideaki Itô',
#  'Blake Burt',
#  'Annekathrin Bach',
#  'Mats Melin',
#  'Chondrea Bryant',
#  'João Guilherme',
#  'Chae Humphrey',
#  'Mathieu Amalric',
#  'Zac Camburn',
#  "Danilo 'Bata' Stojkovic",
#  'Danielle Motley',
#  'Johnny Weir',
#  'Yaroslava Nikolaeva',
#  'Maurice Clairmont',
#  'Eric Peter-Kaiser',
#  'Grahame Bond',
#  'Peter Zhmutski',
#  'José Mário Austregésilo',
#  'Cecilia Samuelsson',
#  'Ian Jareth Williamson',
#  'Sean Hewitt',
#  'Gô Wakabayashi',
#  'Sharjil Arshed',
#  'Peter Judson',
#  'Alexander Stille',
#  'Lauren Hewett',
#  'Jonathon Allen',
#  'Aleksandr Utochkin',
#  'Rafal Rutkowski',
#  'Paolo Congiu',
#  'Rick Scandlin',
#  'Shahiduzzaman Selim',
#  'Bong-sik Hyun',
#  'Brian Firkus',
#  'Ilkka Koivula',
#  'Elizabeth Ruscio',
#  'Lisa-Gabrielle Greene',
#  'Sayaka Umemiya',
#  'Kimberly Igiebor-Iskoen',
#  'Ed Blau',
#  'Nilgün Altinel',
#  'Paola Crova',
#  'Thomas Beatty',
#  'Kat Foster',
#  'Moriya Ben-Harush',
#  'Randy Davison',
#  'Kyle Howard',
#  'Megan Dalby',
#  'Colby French',
#  'Luis Carcia',
#  'Krista Gano',
#  'Jordan Poole',
#  'Gil Brenton',
#  'Christopher Evans',
#  'Alexander May',
#  'Karmen Azzopardi',
#  'Navakesh',
#  'Otis Redding',
#  'Ashleigh Chanel',
#  'Clery Cunha',
#  'Rafael Warner',
#  'Devin Brochu',
#  'Marion Krawitz',
#  'Caitlin Brown',
#  'Salvatore Di Costanzo',
#  'Ernesto Cardenal',
#  'Chris Briant',
#  'Joshua Haze',
#  'Edu Boxer',
#  'James Foley',
#  'Fujimi Nadeki',
#  'Vera Kresadlová',
#  'Jasmine Givenchy Blahnik',
#  "David 'Coondog' O'Karma",
#  'Naima Silva',
#  'Sabrina Draoui',
#  'Shawn D. White',
#  'Roger Dube',
#  'Britt Bendixen',
#  'Kye Korabelnikov',
#  'Alisa Lebow',
#  'Brian Schmeck',
#  'Kim Cifuentes',
#  'Alan Blyton',
#  'Julio Garcia',
#  'Patricia Bouvier',
#  'Serge Nicoloff',
#  'Meena Kumari Perera',
#  'Dhanashree Dalvi',
#  'Prathamesh Parab',
#  'Lao An',
#  'Tom Glod',
#  'Len Cariou',
#  'Juana Cordero',
#  'Alhassane Barry',
#  'Muho Nölke',
#  'Mata Koppala',
#  'Ezzedine Brika',
#  'Nati Apaza',
#  'Navjot Hansra',
#  'Alberto Regalado',
#  'Jerry Butler',
#  'El Hollywood Boricua',
#  'Leah Egan',
#  'Marie-Claude Hamel',
#  'Elena Fondevila',
#  'Aline Amouret',
#  'Rudolf Schindler',
#  'Konstantin Jagoulis',
#  'Isaac Luria',
#  ...}

# %%
len(actors)
# Out:
# 407619

# %% [markdown]
# Pull one actor

# %%
name = "Jonathan Majors"

# %%
df = data.loc[data.stars.str.contains(name)].reset_index()
df.drop("index", axis=1, inplace=True)
df
# Out:
#         uids                               titles                  genres  \
# 0  tt5968394                        Captive State  Action, Horror, Sci-Fi
# 1  tt4353250  The Last Black Man in San Francisco                   Drama
# 2  tt5013984                                Gully            Crime, Drama
# 3  tt9777644                          Da 5 Bloods   Adventure, Drama, War
#
#   ratings  scores  votes  lengths       directors  \
# 0   PG-13     6.0  48959      109    Rupert Wyatt
# 1       R     7.3  14764      121      Joe Talbot
# 2    None     1.5    981       90  Nabil Elderkin
# 3       R     6.5  40553      154       Spike Lee
#
#                                                stars  \
# 0  John Goodman, Ashton Sanders, Jonathan Majors,...
# 1  Jimmie Fails, Jonathan Majors, Rob Morgan, Tic...
# 2  Amber Heard, John Corbett, Terrence Howard, Jo...
# 3  Delroy Lindo, Jonathan Majors, Clarke Peters, ...
#
#                                         descriptions  year
# 0  Set in a Chicago neighborhood nearly a decade ...  2019
# 1  A young man searches for home in the changing ...  2019
# 2  A slightly dystopian vision of LA, we follow t...  2019
# 3  Four African-American vets battle the forces o...  2020

# %% [markdown]
# Explore weighted averages for movies pertaining to a chosen actor

# %%
def weighted_scoring(df, min_voters=1000):
    
    deets = np.array(df[["scores", "votes"]])
    cluster_score = df.loc[df.votes > min_voters, "scores"].mean()
    
    weighted_list = []
    for sample in deets:
        avg_score = sample[0]
        num_voters = sample[1]
        
        common_denominator = (num_voters + min_votes)
        wr = (num_voters * avg_score) / common_denominator + (cluster_score * min_voters) / common_denominator
        weighted_list.append(wr)
        
    df["Weighted_score"] = weighted_list
    
    df = df.sort_values(by="Weighted_score", ascending=False)
    
    return df

# %%
dfnew = weighted_scoring(df)
dfnew
# Out:
#                                   Film                   Genre Rating  \
# 1  The Last Black Man in San Francisco                   Drama      R
# 3                          Da 5 Bloods   Adventure, Drama, War      R
# 0                        Captive State  Action, Horror, Sci-Fi  PG-13
# 2                                Gully            Crime, Drama   None
#
#    Runtime        Director                                      Also starring  \
# 1      121      Joe Talbot  Jimmie Fails, Jonathan Majors, Rob Morgan, Tic...
# 3      154       Spike Lee  Delroy Lindo, Jonathan Majors, Clarke Peters, ...
# 0      109    Rupert Wyatt  John Goodman, Ashton Sanders, Jonathan Majors,...
# 2       90  Nabil Elderkin  Amber Heard, John Corbett, Terrence Howard, Jo...
#
#                                          Description  Year  Weighted_score
# 1  A young man searches for home in the changing ...  2019        7.255595
# 3  Four African-American vets battle the forces o...  2020        6.502407
# 0  Set in a Chicago neighborhood nearly a decade ...  2019        6.012010
# 2  A slightly dystopian vision of LA, we follow t...  2019        4.074457

# %%
def reccommend_byActor(name):
    name = name.title()
    
    df = data.loc[data.stars.str.contains(name)].reset_index()
    df.drop("index", axis=1, inplace=True)
    
    # obtain sorted, weighted scores
    df = weighted_scoring(df)
    
    # drop extraneous columns
    df.drop(["uids", "scores", "votes"], axis=1, inplace=True)
    
    # remove the searched name from the stars list
    # the actor is known to be in the returned movies, so only return the names of other actors

    for i in range(df.shape[0]):
        tmp = df.loc[i, "stars"].replace(", ",",").split(',')
        tmp.remove(n)
        entry = ", ".join(tmp)
        df.loc[i, "stars"] = entry
    
    df.reset_index(inplace=True)
    
    df["index"] = list(df.index +1)
    
    mapper = {"index": "Rank", "titles": "Film", "genres":"Genre", "ratings":"Rating", "scores":"Score",
              "lengths":"Runtime", "directors":"Director", "stars": "Also starring",
              "descriptions": "Description", "year": "Year", "Weighted_score": "Score"}
    
    df = df.rename(columns=mapper)
    
    print(f"Top Recommended Movies with {name}")
    return df

# %%
name = "JonatHAn majors"

# %%
df = reccommend_byActor(name)
df
# Out:
# Top Recommended Movies with Jonathan Majors
#    Rank                                 Film                   Genre Rating  \
# 0     1  The Last Black Man in San Francisco                   Drama      R
# 1     2                          Da 5 Bloods   Adventure, Drama, War      R
# 2     3                        Captive State  Action, Horror, Sci-Fi  PG-13
# 3     4                                Gully            Crime, Drama   None
#
#    Runtime        Director                               Also starring  \
# 0      121      Joe Talbot    Jimmie Fails, Rob Morgan, Tichina Arnold
# 1      154       Spike Lee     Delroy Lindo, Clarke Peters, Norm Lewis
# 2      109    Rupert Wyatt  John Goodman, Ashton Sanders, Vera Farmiga
# 3       90  Nabil Elderkin  Amber Heard, John Corbett, Terrence Howard
#
#                                          Description  Year     Score
# 0  A young man searches for home in the changing ...  2019  7.255595
# 1  Four African-American vets battle the forces o...  2020  6.502407
# 2  Set in a Chicago neighborhood nearly a decade ...  2019  6.012010
# 3  A slightly dystopian vision of LA, we follow t...  2019  4.074457

# %%
df["Rank"] = list(df.index +1)

# %%
for i in range(df.shape[0]):
    n = name.title()
    tmp = df.loc[i, "Also starring"].replace(", ",",").split(',')
    tmp.remove(n)
    entry = ", ".join(tmp)
    print(entry)
# Out:
# John Goodman, Ashton Sanders, Vera Farmiga
# Jimmie Fails, Rob Morgan, Tichina Arnold
# Amber Heard, John Corbett, Terrence Howard
# Delroy Lindo, Clarke Peters, Norm Lewis

# %%
name
# Out:
# 'JonatHAn majors'

# %%
df.loc[0].Description
# Out:
# "Set in a Chicago neighborhood nearly a decade after an occupation by an extraterrestrial force, 'Captive State' explores the lives on both sides of the conflict - the collaborators and dissidents."
